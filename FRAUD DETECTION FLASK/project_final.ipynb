# %%
#Ignore the warnings

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
import sklearn
import random

# %%
from sklearn.utils import shuffle
# %matplotlib inline

# %%
data=pd.read_csv('creditcard.csv')

# %%
sns.distplot(data['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
sns.distplot(data['Time'])
# Out:
# <Axes: xlabel='Time', ylabel='Density'>

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
sns.jointplot(x= 'Time', y= 'Amount', data= data)
class0 = data[data['Class']==0]

# %%
len(class0)
# Out:
# 284315

# %%
class1 = data[data['Class']==1]

# %%
len(class1)
# Out:
# 492

# %%
class0
temp = shuffle(class0)

# %%
d1 = temp.iloc[:2000,:]

# %%
d1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 156047  107132.0  1.871065 -0.446558 -0.516280  0.134838  0.199290  1.305585
# 267774  162925.0  2.041198 -0.218276 -1.405547  0.187570  0.001916 -0.781668
# 48200    43539.0  1.151164 -0.052225  1.282310  1.348357 -1.011786 -0.214879
# 254144  156599.0  1.739537 -0.325237 -1.878548  0.367209  0.284870 -0.471878
# 25868    33805.0  0.208464 -1.448926  0.011501  1.408998 -0.677970  0.446821
# ...          ...       ...       ...       ...       ...       ...       ...
# 152182   97039.0 -0.569412  0.878085  2.215472  4.058860  1.221197  3.509134
# 27175    34424.0 -0.375500 -0.705548  1.688715 -1.120936 -0.044601  0.376191
# 119201   75369.0  1.194159  0.515150  0.168796  2.260234  0.475087  0.368337
# 232660  147255.0 -4.654505  3.058272 -2.187103 -0.550746 -1.611089 -1.195121
# 277910  167930.0 -0.440090  1.101111 -0.035594 -0.877063  0.513922 -0.677941
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 156047 -0.969221  0.493351  2.573605  ... -0.191405 -0.155545  0.372195
# 267774 -0.043787 -0.090115  0.677407  ...  0.273900  0.844092 -0.023770
# 48200  -0.576789  0.104641  0.933079  ... -0.064982  0.005248 -0.001951
# 254144  0.151051 -0.079287  0.669190  ... -0.121699 -0.409764  0.104553
# 25868   0.295656  0.093889 -0.043634  ...  0.516544  0.419136 -0.572712
# ...          ...       ...       ...  ...       ...       ...       ...
# 152182 -0.047658  0.662686 -0.537675  ...  0.129690  0.645806 -0.162207
# 27175  -0.574064  0.097938 -0.990131  ... -0.146369  0.008341 -0.097992
# 119201  0.121977  0.017111 -0.752829  ...  0.101885  0.317694 -0.209935
# 232660 -0.896774  1.848771  0.187672  ...  0.134227 -0.416553  0.231663
# 277910  0.834122  0.006767  0.166438  ... -0.296206 -0.597802  0.040673
#
#              V24       V25       V26       V27       V28  Amount  Class
# 156047 -1.785783 -0.593381 -0.846649  0.069305 -0.062983    2.98      0
# 267774 -0.407890  0.190140 -0.089576 -0.029237 -0.075626    1.00      0
# 48200   0.375836  0.404948 -0.407846  0.070661  0.037744    9.99      0
# 254144  0.593049 -0.125222 -0.153226 -0.030983  0.000813  132.56      0
# 25868  -0.270926  0.366690 -0.239876 -0.047788  0.094604  492.50      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 152182 -1.048263 -0.053509  0.586165 -0.069293 -0.148085   81.90      0
# 27175  -0.977458 -0.586754  1.168845 -0.084193 -0.092556   38.00      0
# 119201 -0.748917  0.689462  0.226001  0.000039  0.008746   15.00      0
# 232660 -0.055441  0.074317 -0.693540 -2.722218 -0.635301   18.63      0
# 277910 -0.361881 -0.388912  0.151347  0.451336  0.210067    2.58      0
#
# [2000 rows x 31 columns]

# %%
frames = [d1, class1]
df_temp = pd.concat(frames)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2492 entries, 156047 to 281674
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2492 non-null   float64
#  1   V1      2492 non-null   float64
#  2   V2      2492 non-null   float64
#  3   V3      2492 non-null   float64
#  4   V4      2492 non-null   float64
#  5   V5      2492 non-null   float64
#  6   V6      2492 non-null   float64
#  7   V7      2492 non-null   float64
#  8   V8      2492 non-null   float64
#  9   V9      2492 non-null   float64
#  10  V10     2492 non-null   float64
#  11  V11     2492 non-null   float64
#  12  V12     2492 non-null   float64
#  13  V13     2492 non-null   float64
#  14  V14     2492 non-null   float64
#  15  V15     2492 non-null   float64
#  16  V16     2492 non-null   float64
#  17  V17     2492 non-null   float64
#  18  V18     2492 non-null   float64
#  19  V19     2492 non-null   float64
#  20  V20     2492 non-null   float64
#  21  V21     2492 non-null   float64
#  22  V22     2492 non-null   float64
#  23  V23     2492 non-null   float64
#  24  V24     2492 non-null   float64
#  25  V25     2492 non-null   float64
#  26  V26     2492 non-null   float64
#  27  V27     2492 non-null   float64
#  28  V28     2492 non-null   float64
#  29  Amount  2492 non-null   float64
#  30  Class   2492 non-null   int64
# dtypes: float64(30), int64(1)
# memory usage: 623.0 KB

# %%
df= shuffle(df_temp)

# %%
df.to_csv('creditcardsampling.csv')

# %%
df
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 145040   86579.0  -0.318485   0.969566  -0.092594 -1.256885   0.969415
# 233420  147557.0   2.037556   0.276439  -2.113543  0.934373   1.089666
# 17317    28625.0 -27.848181  15.598193 -28.923756  6.418442 -20.346228
# 276314  167013.0   2.011129   0.060272  -1.621478  0.341736   0.363086
# 43003    41332.0   1.240703  -0.640674   0.155634 -0.842173  -0.527249
# ...          ...        ...        ...        ...       ...        ...
# 153860  100408.0   1.703720  -1.257298  -0.271565 -1.051581  -1.356500
# 182424  125394.0   2.097284  -0.117219  -1.371351  0.250875   0.187972
# 234639  148055.0   0.095910   0.809176  -0.252801 -1.026060   1.161995
# 48865    43816.0   0.977262  -1.755199   0.441279 -1.130711  -1.856058
# 111249   72158.0   1.326420  -0.776705   0.134041 -1.572105  -1.132407
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 145040 -0.800743   1.127303  -0.158599 -0.173575  ...  0.396862  1.289004
# 233420 -0.448318   0.658672  -0.248777 -0.403741  ...  0.153800  0.472470
# 17317  -4.828202 -19.210896  18.329406 -3.668735  ...  1.802149 -2.062934
# 276314 -0.588496   0.029151  -0.039706  0.314429  ... -0.302720 -0.826202
# 43003   0.102999  -0.586446   0.129054 -1.169337  ...  0.337393  0.879815
# ...          ...        ...        ...       ...  ...       ...       ...
# 153860 -0.827497  -0.743136  -0.166954  3.735146  ... -0.003123  0.112730
# 182424 -0.737671   0.129673  -0.240711  0.652417  ... -0.332716 -0.840797
# 234639 -0.000378   0.923426  -0.000486 -0.282214  ... -0.292110 -0.672619
# 48865  -0.780822  -0.621237  -0.325485 -1.983034  ... -0.188062 -0.741167
# 111249 -0.890874  -0.526521  -0.071098  0.310659  ... -0.397076 -0.644389
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 145040 -0.281079 -0.359507 -0.415910 -0.351131  0.315546  0.266367    1.29
# 233420 -0.040112  0.290940  0.496090 -0.510054 -0.039840 -0.069227   14.35
# 17317  -1.269843  0.165409  1.999499 -0.211059  1.324809  0.388090   99.99
# 276314  0.363997  0.593278 -0.347886  0.150382 -0.067069 -0.040793    1.29
# 43003  -0.091003 -0.237526  0.443587 -0.078167  0.018042 -0.001350   39.85
# ...          ...       ...       ...       ...       ...       ...     ...
# 153860  0.135948 -0.053533 -0.482279 -0.387780 -0.006192 -0.011484  174.40
# 182424  0.263205 -0.725839 -0.235478  0.245618 -0.071774 -0.068051    4.45
# 234639 -0.111800 -1.380425 -0.320075  0.204010  0.243798  0.074496    5.85
# 48865  -0.077847  0.386587  0.079473 -0.443805  0.000655  0.080299  285.70
# 111249  0.065874  0.001661  0.379536 -0.703653  0.078468  0.026512   24.60
#
#         Class
# 145040      0
# 233420      0
# 17317       1
# 276314      0
# 43003       0
# ...       ...
# 153860      0
# 182424      0
# 234639      0
# 48865       0
# 111249      0
#
# [2492 rows x 31 columns]

# %%
sns.countplot(x='Class', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
import imblearn
from imblearn.over_sampling import  SMOTE,RandomOverSampler
oversample=RandomOverSampler()
X=df.iloc[ : ,:-1]
Y=df.iloc[: , -1]
X,Y=oversample.fit_resample(X,Y)
X=pd.DataFrame(X)
X.shape
# Out:
# (4000, 30)

# %%
Y=pd.DataFrame(Y)
Y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
names=['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount','Class']
data=pd.concat([X,Y],axis=1)
d=data.values

# %%
data=pd.DataFrame(d,columns=names)
sns.countplot(x='Class', data=data)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
data.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean    88361.202500    -2.307660     1.730806    -3.453049     2.258759
# std     48336.704387     5.362535     3.619138     6.099154     3.213508
# min       283.000000   -31.322895   -30.064036   -31.103685    -3.992323
# 25%     47296.750000    -2.869795    -0.189923    -5.111658    -0.145011
# 50%     79540.000000    -0.769172     0.942289    -1.386084     1.307781
# 75%    135314.000000     1.055079     2.777569     0.324833     4.247831
# max    172710.000000     2.340594    22.057729     3.311284    12.114672
#
#                 V5           V6           V7           V8           V9  ...  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  ...
# mean     -1.537640    -0.712711    -2.701650     0.306109    -1.292978  ...
# std       4.074749     1.678449     5.592479     4.641036     2.258655  ...
# min     -22.105532    -6.885337   -43.557242   -41.044261   -13.434066  ...
# 25%      -1.758911    -1.555033    -3.039520    -0.222770    -2.336584  ...
# 50%      -0.448525    -0.654659    -0.663549     0.133080    -0.723486  ...
# 75%       0.458307     0.085170     0.284096     0.878417     0.147126  ...
# max      11.095089     6.474115     7.278028    20.007208     6.366108  ...
#
#                V21          V22          V23          V24          V25  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.400775    -0.009292    -0.043216    -0.062632     0.023639
# std       2.724561     1.154264     1.312691     0.549971     0.684244
# min     -22.797604    -8.887017   -19.254328    -2.028024    -4.781606
# 25%      -0.176541    -0.541855    -0.243949    -0.403114    -0.298089
# 50%       0.143140     0.017495    -0.037906     0.001669     0.061612
# 75%       0.641594     0.592670     0.193140     0.350351     0.390803
# max      27.202839     8.361985    10.377233     1.201609     2.208209
#
#                V26          V27          V28       Amount        Class
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.028157     0.119088     0.033417   110.385910     0.500000
# std       0.471941     0.956391     0.493754   239.106657     0.500063
# min      -1.317944    -7.263482    -2.735623     0.000000     0.000000
# 25%      -0.283738    -0.059523    -0.058079     1.565000     0.000000
# 50%      -0.007772     0.057263     0.035075    19.625000     0.500000
# 75%       0.333848     0.473934     0.218773    99.990000     1.000000
# max       2.745261     3.394531    15.619041  3454.920000     1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    4000 non-null   float64
#  1   V1      4000 non-null   float64
#  2   V2      4000 non-null   float64
#  3   V3      4000 non-null   float64
#  4   V4      4000 non-null   float64
#  5   V5      4000 non-null   float64
#  6   V6      4000 non-null   float64
#  7   V7      4000 non-null   float64
#  8   V8      4000 non-null   float64
#  9   V9      4000 non-null   float64
#  10  V10     4000 non-null   float64
#  11  V11     4000 non-null   float64
#  12  V12     4000 non-null   float64
#  13  V13     4000 non-null   float64
#  14  V14     4000 non-null   float64
#  15  V15     4000 non-null   float64
#  16  V16     4000 non-null   float64
#  17  V17     4000 non-null   float64
#  18  V18     4000 non-null   float64
#  19  V19     4000 non-null   float64
#  20  V20     4000 non-null   float64
#  21  V21     4000 non-null   float64
#  22  V22     4000 non-null   float64
#  23  V23     4000 non-null   float64
#  24  V24     4000 non-null   float64
#  25  V25     4000 non-null   float64
#  26  V26     4000 non-null   float64
#  27  V27     4000 non-null   float64
#  28  V28     4000 non-null   float64
#  29  Amount  4000 non-null   float64
#  30  Class   4000 non-null   float64
# dtypes: float64(31)
# memory usage: 968.9 KB

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
import math
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score , classification_report, confusion_matrix, precision_recall_curve, f1_score, auc
X_train, X_test, y_train, y_test = train_test_split(data.drop('Class', axis=1), data['Class'], test_size=0.3, random_state=42)

# %%
cols= ['V22', 'V24', 'V25', 'V26', 'V27', 'V28']

# %%
scaler = StandardScaler()

# %%
frames= ['Time', 'Amount']

# %%
x= data[frames]

# %%
d_temp = data.drop(frames, axis=1)

# %%
temp_col=scaler.fit_transform(x)

# %%
scaled_col = pd.DataFrame(temp_col, columns=frames)

# %%
scaled_col.head()
# Out:
#        Time    Amount
# 0 -0.036875 -0.456322
# 1  1.224808 -0.401695
# 2 -1.235990 -0.043484
# 3  1.627369 -0.456322
# 4 -0.973072 -0.295035

# %%
d_scaled = pd.concat([scaled_col, d_temp], axis =1)

# %%
d_scaled.head()
# Out:
#        Time    Amount         V1         V2         V3        V4         V5  \
# 0 -0.036875 -0.456322  -0.318485   0.969566  -0.092594 -1.256885   0.969415
# 1  1.224808 -0.401695   2.037556   0.276439  -2.113543  0.934373   1.089666
# 2 -1.235990 -0.043484 -27.848181  15.598193 -28.923756  6.418442 -20.346228
# 3  1.627369 -0.456322   2.011129   0.060272  -1.621478  0.341736   0.363086
# 4 -0.973072 -0.295035   1.240703  -0.640674   0.155634 -0.842173  -0.527249
#
#          V6         V7         V8  ...       V20       V21       V22  \
# 0 -0.800743   1.127303  -0.158599  ... -0.128360  0.396862  1.289004
# 1 -0.448318   0.658672  -0.248777  ... -0.217436  0.153800  0.472470
# 2 -4.828202 -19.210896  18.329406  ...  1.697856  1.802149 -2.062934
# 3 -0.588496   0.029151  -0.039706  ... -0.197591 -0.302720 -0.826202
# 4  0.102999  -0.586446   0.129054  ...  0.074271  0.337393  0.879815
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.281079 -0.359507 -0.415910 -0.351131  0.315546  0.266367    0.0
# 1 -0.040112  0.290940  0.496090 -0.510054 -0.039840 -0.069227    0.0
# 2 -1.269843  0.165409  1.999499 -0.211059  1.324809  0.388090    1.0
# 3  0.363997  0.593278 -0.347886  0.150382 -0.067069 -0.040793    0.0
# 4 -0.091003 -0.237526  0.443587 -0.078167  0.018042 -0.001350    0.0
#
# [5 rows x 31 columns]

# %%
y = data['Class']

# %%
# Dimensionality Reduction
from sklearn.decomposition import PCA
pca = PCA(n_components=7)
X_temp_reduced = pca.fit_transform(d_scaled)

# %%
pca.explained_variance_ratio_
pca.explained_variance_
# Out:
# array([208.97226351,  27.41431162,  23.43344405,  11.82829048,
#          8.94816064,   4.07196702,   2.88363599])

# %%
names=['Time','Amount','Transaction Method','Transaction Id','Location','Type of Card','Bank']

# %%
X_reduced= pd.DataFrame(X_temp_reduced,columns=names)
X_reduced.head()
# Out:
#         Time    Amount  Transaction Method  Transaction Id   Location  \
# 0  -9.428477  0.954890           -1.275804       -1.122560  -0.073511
# 1  -9.374188  0.559471           -0.908077       -0.171560   0.515029
# 2  41.470366  9.515238          -26.443098        4.602550 -10.327831
# 3  -9.238100  0.471450           -0.732763        0.745745   0.334569
# 4  -9.489890  0.688582           -1.147993       -1.266473   0.247197
#
#    Type of Card      Bank
# 0     -0.549352 -0.898323
# 1     -1.084856  0.130832
# 2     -0.815048 -0.716296
# 3     -1.227834  0.153224
# 4     -0.859074 -0.348609

# %%
Y=d_scaled['Class']

# %%
new_data=pd.concat([X_reduced,Y],axis=1)
new_data.head()
# Out:
#         Time    Amount  Transaction Method  Transaction Id   Location  \
# 0  -9.428477  0.954890           -1.275804       -1.122560  -0.073511
# 1  -9.374188  0.559471           -0.908077       -0.171560   0.515029
# 2  41.470366  9.515238          -26.443098        4.602550 -10.327831
# 3  -9.238100  0.471450           -0.732763        0.745745   0.334569
# 4  -9.489890  0.688582           -1.147993       -1.266473   0.247197
#
#    Type of Card      Bank  Class
# 0     -0.549352 -0.898323    0.0
# 1     -1.084856  0.130832    0.0
# 2     -0.815048 -0.716296    1.0
# 3     -1.227834  0.153224    0.0
# 4     -0.859074 -0.348609    0.0

# %%
new_data.shape
# Out:
# (4000, 8)

# %%
new_data.to_csv('finaldata.csv')

# %%
X_train, X_test, y_train, y_test= train_test_split(X_reduced, d_scaled['Class'], test_size = 0.30, random_state = 42)
X_train.shape, X_test.shape
# Out:
# ((2800, 7), (1200, 7))

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf',probability=True)
svc.fit(X_train,y_train)
y_pred_svc=svc.predict(X_test)
y_pred_svc
# Out:
# array([1., 1., 0., ..., 0., 0., 1.])

# %%
type(X_test)
X_test.to_csv('testing.csv')
from sklearn.model_selection import GridSearchCV
parameters = [ {'C': [1, 10, 100, 1000], 'kernel': ['rbf'], 'gamma': [0.1, 1, 0.01, 0.0001 ,0.001]}]
grid_search = GridSearchCV(estimator = svc,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Best Accuracy: 95.96 %
# Best Parameters: {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc_param=SVC(kernel='rbf',gamma=0.01,C=100,probability=True)
svc_param.fit(X_train,y_train)
# Out:
# SVC(C=100, gamma=0.01, probability=True)

# %%
import pickle
# Saving model to disk
pickle.dump(svc_param, open('model.pkl','wb'))

# %%
model=pickle.load(open('model.pkl','rb'))
